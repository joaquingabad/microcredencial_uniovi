# %%
print("hola mundo")
# Out:
# hola mundo

# %% [markdown]
# # Este es nuestro primer notebook
#
# ## Titulo
# ### Subtitulo
#
# - Hola
# - mundo
# -

# %%
import sys

# %%
print(sys.version)
# Out:
# 3.10.20 (main, Mar 11 2026, 17:46:40) [GCC 14.3.0]

# %%
import pandas as pd
import numpy as np

# %%
datos = {"nombre": ["Ana","Carlos","Elena"],
         "puntuacion": [8.5, 7.2, 9.1]}
df = pd.DataFrame(datos)
df
# Out:
#    nombre  puntuacion
# 0     Ana         8.5
# 1  Carlos         7.2
# 2   Elena         9.1

# %%
import matplotlib.pyplot as plt
df.plot(x="nombre", y="puntuacion",
 kind="bar", title="Puntuaciones")
plt.tight_layout()
plt.show()
